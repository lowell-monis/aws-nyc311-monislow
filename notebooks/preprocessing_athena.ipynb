# %% [markdown]
# This notebook will use Athena to create a copy of the preprocessed data via notebook instead of a manual query run and import.

# %%
import boto3
import time

# --- Configuration ---
DATABASE = 'nyc311_db'
TABLE_NAME = 'resolution_speed_modeling'
S3_OUTPUT = 's3://cmse492-monislow-nyc311-975049958391-us-east-1-an/path/' # Change this to your bucket

athena = boto3.client('athena')
